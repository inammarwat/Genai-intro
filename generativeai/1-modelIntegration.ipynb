# %%
import langchain
print (langchain.__version__)
# Out:
# 1.2.3

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Generative AI applications with GemeniAI Model

# %%
from langchain.chat_models import init_chat_model

# Load Gemini
model = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

response = model.invoke("write an essay on the topic of the benefits of AI")
print(response.content)
# Out:
# ## The Unfolding Promise: Unpacking the Benefits of Artificial Intelligence
#
# Artificial Intelligence (AI), once a staple of science fiction, has rapidly evolved into a transformative force shaping our present and future. Far from being a mere technological novelty, AI stands as a monumental force for good, promising a future characterized by unprecedented efficiency, groundbreaking innovation, and enriched human experiences across virtually every sector. By augmenting human capabilities, automating mundane tasks, and unveiling insights from vast datasets, AI is proving to be an indispensable tool for progress, prosperity, and problem-solving on a global scale.
#
# One of AI's most immediate and palpable benefits lies in its capacity for automation and efficiency. By performing repetitive, high-volume tasks with speed and accuracy far exceeding human capabilities, AI liberates human workers from monotonous labor. In manufacturing, AI-powered robots enhance production lines, reducing errors and increasing output. In customer service, intelligent chatbots handle routine inquiries, providing instant support and freeing human agents to address more complex issues. This automation not only boosts productivity and lowers operational costs but also allows human employees to pivot towards more creative, strategic, and fulfilling roles that leverage uniquely human skills such as critical thinking, empathy, and innovation.
#
# Beyond mere automation, AI's true analytical prowess shines in its ability to process, interpret, and derive insights from vast datasets at an unparalleled scale. In fields ranging from scientific research to financial analysis, AI algorithms can identify patterns, predict trends, and make informed recommendations with remarkable precision. Medical diagnostics benefit immensely, with AI assisting in the early detection of diseases like cancer by analyzing complex imaging data, often outperforming human specialists. Climate modeling, urban planning, and resource management also leverage AI to understand complex systems, optimize resource allocation, and develop more sustainable solutions. This data-driven insight empowers better decision-making, accelerating discovery and mitigating risks across countless domains.
#
# AI also champions a more human-centric future through its ability to personalize experiences and enhance accessibility. In education, AI-powered learning platforms can adapt to individual student paces and learning styles, offering tailored content and feedback that maximizes comprehension and engagement. In healthcare, precision medicine, driven by AI, analyzes a patient's genetic makeup, lifestyle, and medical history to recommend highly personalized treatment plans. Furthermore, AI-driven assistive technologies are breaking down barriers for individuals with disabilities, offering tools like real-time speech-to-text conversion, image recognition for the visually impaired, and smart prosthetics, thereby fostering greater independence and inclusivity.
#
# Perhaps most profoundly, AI is accelerating the pace of innovation in critical fields that address humanity's grand challenges. In medicine, AI is revolutionizing drug discovery by rapidly screening compounds and predicting their efficacy, significantly shortening development timelines and bringing life-saving treatments to market faster. Environmental monitoring benefits from AI's ability to track pollution, deforestation, and climate change indicators, providing crucial data for conservation efforts. From developing smarter cities with optimized traffic flow and energy grids to enhancing agricultural yields through predictive analytics, AI serves as a powerful catalyst for breakthroughs that improve quality of life and pave the way for a more sustainable future.
#
# In conclusion, the benefits of Artificial Intelligence are vast and transformative, extending far beyond initial expectations. From revolutionizing industries through automation and advanced data analysis to fostering personalized experiences and catalyzing scientific breakthroughs, AI is proving to be an invaluable partner in human progress. While its responsible development and ethical deployment are paramount, the judicious integration of AI promises to unlock a future of unparalleled efficiency, innovation, and human flourishing, augmenting our capabilities and expanding the horizons of what is truly possible. As we continue to harness its potential, AI stands poised to lead us into an era of unprecedented advancement and a better quality of life for all.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response = model.invoke("Hello, how are you?")

print(response.content)
# Out:
# Hello! I'm doing well, thank you for asking.
#
# How are you today?

# %% [markdown]
# ### Generative AI applications with Groq AI Model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

response = model.invoke("Explain the Artificial Intelligence")
print(response.content)
# Out:
# **Introduction to Artificial Intelligence**
#
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:
#
# 1. **Learning**: AI systems can learn from data and improve their performance over time.
# 2. **Problem-solving**: AI systems can analyze problems and find solutions.
# 3. **Reasoning**: AI systems can draw inferences and make decisions based on available data.
# 4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.
#
# **Types of Artificial Intelligence**
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playing chess.
# 2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.
# 3. **Superintelligence**: An AI system that is significantly more intelligent than the best human minds.
# 4. **Cognitive AI**: Focuses on simulating human thought processes, such as reasoning, decision-making, and problem-solving.
#
# **Key Concepts in Artificial Intelligence**
#
# 1. **Machine Learning**: A subset of AI that involves training algorithms on data to enable them to make predictions or decisions.
# 2. **Deep Learning**: A type of machine learning that uses neural networks to analyze data.
# 3. **Natural Language Processing (NLP)**: The ability of AI systems to understand, interpret, and generate human language.
# 4. **Computer Vision**: The ability of AI systems to interpret and understand visual data from images and videos.
#
# **Applications of Artificial Intelligence**
#
# 1. **Virtual Assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, can perform tasks such as setting reminders, sending messages, and making calls.
# 2. **Image and Speech Recognition**: AI-powered systems can recognize and interpret images and speech, enabling applications such as facial recognition, speech-to-text, and language translation.
# 3. **Autonomous Vehicles**: AI-powered systems can control and navigate vehicles, enabling self-driving cars and trucks.
# 4. **Healthcare**: AI-powered systems can analyze medical data, diagnose diseases, and develop personalized treatment plans.
#
# **Benefits and Challenges of Artificial Intelligence**
#
# **Benefits:**
#
# 1. **Improved Efficiency**: AI can automate repetitive tasks, freeing up human resources for more strategic and creative work.
# 2. **Enhanced Decision-Making**: AI can analyze large datasets and provide insights that can inform decision-making.
# 3. **Personalization**: AI can enable personalized experiences, such as tailored recommendations and customized products.
#
# **Challenges:**
#
# 1. **Job Displacement**: AI can automate jobs, potentially displacing human workers.
# 2. **Bias and Discrimination**: AI systems can perpetuate biases and discrimination if they are trained on biased data.
# 3. **Security and Privacy**: AI systems can pose security and privacy risks if they are not designed and implemented with robust security measures.
#
# **Conclusion**
#
# Artificial Intelligence has the potential to transform numerous aspects of our lives, from healthcare and education to transportation and entertainment. However, it also raises important questions about the future of work, bias and discrimination, and security and privacy. As AI continues to evolve, it is essential to address these challenges and ensure that AI is developed and used in a responsible and beneficial manner.

# %%
from langchain_groq import ChatGroq 
model = ChatGroq(model="llama-3.3-70b-versatile")

response = model.invoke("Hello, how are you?")
print(response.content)
# Out:
# Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you. How can I help you today?

# %% [markdown]
# ### Streaming
# LLM streaming techniques involve sending text chunks (tokens) as they're generated, not waiting for the full response, drastically improving user experience by showing real-time output in applications like chatbots.

# %%
for chunk in model.stream("write me a 1000 words on the topic of AI"):
    print(chunk.text, end="", flush=True)
# Out:
# **The Era of Artificial Intelligence: Transforming the World as We Know It**
#
# Artificial Intelligence (AI) has been a topic of interest and debate for decades, with its roots dating back to the 1950s. However, it's only in recent years that AI has started to make its presence felt in various aspects of our lives. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI is transforming the world at an unprecedented pace. In this article, we'll delve into the world of AI, exploring its history, types, applications, and the potential impact it may have on our future.
#
# **A Brief History of AI**
#
# The concept of AI was first introduced by computer scientist Alan Turing in his 1950 paper, "Computing Machinery and Intelligence." Turing proposed a simple test to measure a machine's ability to exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human. This test, known as the Turing Test, has since become a benchmark for AI research.
#
# In the early days of AI, researchers focused on developing machines that could perform tasks that typically required human intelligence, such as problem-solving, reasoning, and learning. The first AI program, called Logical Theorist, was developed in 1956 by Allen Newell and Herbert Simon. This program was designed to simulate human problem-solving abilities and was the first to use a reasoning-based approach to solve problems.
#
# Over the years, AI research has evolved significantly, with the development of new technologies and techniques. The 1980s saw the rise of expert systems, which were designed to mimic human decision-making abilities in specific domains. The 1990s and 2000s witnessed the emergence of machine learning, a subset of AI that enables machines to learn from data without being explicitly programmed.
#
# **Types of AI**
#
# AI can be categorized into several types, each with its unique characteristics and applications. Some of the most common types of AI include:
#
# 1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, such as facial recognition, language translation, or playing chess. Narrow AI is the most common type of AI and is used in many applications, including virtual assistants, chatbots, and image recognition systems.
# 2. **General or Strong AI**: This type of AI is designed to perform any intellectual task that a human can. General AI is still in its infancy, but researchers are working to develop machines that can learn, reason, and apply knowledge across a wide range of tasks.
# 3. **Superintelligence**: This type of AI refers to machines that are significantly more intelligent than humans. Superintelligence is still a topic of debate, with some researchers arguing that it's a potential risk to humanity, while others believe it could have numerous benefits.
#
# **Applications of AI**
#
# AI has a wide range of applications across various industries, including:
#
# 1. **Healthcare**: AI is being used to develop personalized medicine, diagnose diseases, and improve patient outcomes. For example, AI-powered algorithms can analyze medical images to detect diseases such as cancer and diabetes.
# 2. **Finance**: AI is being used to detect fraud, predict stock prices, and optimize investment portfolios. For example, AI-powered chatbots can help customers with financial queries and provide personalized investment advice.
# 3. **Transportation**: AI is being used to develop self-driving cars, optimize traffic flow, and improve logistics. For example, AI-powered systems can analyze traffic patterns and adjust traffic lights to reduce congestion.
# 4. **Education**: AI is being used to develop personalized learning systems, grade assignments, and provide feedback to students. For example, AI-powered adaptive learning systems can adjust the difficulty level of course materials based on a student's performance.
# 5. **Customer Service**: AI is being used to develop chatbots, virtual assistants, and customer service platforms. For example, AI-powered chatbots can help customers with queries, provide product recommendations, and resolve issues.
#
# **The Future of AI**
#
# As AI continues to evolve, we can expect to see significant advancements in various areas, including:
#
# 1. **Natural Language Processing (NLP)**: AI-powered NLP systems will become more sophisticated, enabling machines to understand and generate human-like language.
# 2. **Computer Vision**: AI-powered computer vision systems will become more accurate, enabling machines to recognize and interpret visual data.
# 3. **Robotics**: AI-powered robots will become more autonomous, enabling them to perform tasks that require human-like dexterity and agility.
# 4. **Autonomous Vehicles**: AI-powered self-driving cars will become more common, revolutionizing the transportation industry and reducing accidents caused by human error.
#
# However, the development of AI also raises several concerns, including:
#
# 1. **Job Displacement**: AI could potentially displace human workers, particularly in industries where tasks are repetitive or can be automated.
# 2. **Bias and Discrimination**: AI systems can perpetuate biases and discriminate against certain groups of people, particularly if they are trained on biased data.
# 3. **Security Risks**: AI systems can be vulnerable to cyber attacks, particularly if they are not designed with security in mind.
# 4. **Ethics**: AI raises several ethical concerns, including the potential for machines to make decisions that are not in the best interest of humans.
#
# **Conclusion**
#
# AI is transforming the world at an unprecedented pace, with its applications ranging from healthcare and finance to transportation and education. As AI continues to evolve, we can expect to see significant advancements in various areas, including NLP, computer vision, robotics, and autonomous vehicles. However, the development of AI also raises several concerns, including job displacement, bias and discrimination, security risks, and ethics. To ensure that AI benefits humanity, it's essential to develop and deploy AI systems in a responsible and transparent manner, with a focus on addressing these concerns and ensuring that AI is used for the greater good.
#
# **The Future of Work**
#
# As AI continues to automate tasks and displace human workers, it's essential to rethink the future of work. This may involve:
#
# 1. **Upskilling and Reskilling**: Providing workers with the skills they need to work alongside AI systems.
# 2. **Lifelong Learning**: Encouraging workers to adopt a lifelong learning approach, where they continuously update their skills to remain relevant in the job market.
# 3. **Universal Basic Income**: Implementing a universal basic income to ensure that all citizens have a minimum standard of living, regardless of their employment status.
# 4. **Social Safety Nets**: Developing social safety nets to support workers who are displaced by AI, including unemployment benefits, training programs, and career counseling.
#
# By addressing these concerns and developing AI in a responsible and transparent manner, we can ensure that AI benefits humanity and creates a better future for all. As we move forward into the era of AI, it's essential to be aware of the potential risks and benefits and to work together to create a future where AI enhances human life, rather than replacing it.

# %% [markdown]
# ### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel.

# %%
responses = model.batch(
    [
        "What is the capital of France?",
        "What is the capital of Germany?",
        "What is quantum computing describe briefly?"
    ]
)
for response in responses:
    print(response)
# Out:
# content='The capital of France is Paris.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.011444323, 'completion_tokens_details': None, 'prompt_time': 0.00220132, 'prompt_tokens_details': None, 'queue_time': 0.008330202, 'total_time': 0.013645643}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019bb57e-bd1e-7671-9824-93725fa131fa-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50}
# content='The capital of Germany is Berlin.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.011193094, 'completion_tokens_details': None, 'prompt_time': 0.002219021, 'prompt_tokens_details': None, 'queue_time': 0.008058689, 'total_time': 0.013412115}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019bb57e-bd24-7962-8ec0-e845cfdc7329-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50}
# content='Quantum computing is a type of computing that uses the principles of quantum mechanics to perform calculations and operations on data. It uses quantum bits (qubits) that can exist in multiple states simultaneously, allowing for faster and more complex calculations than classical computers. This enables quantum computers to solve certain problems exponentially faster than classical computers, making them potentially powerful tools for fields like cryptography, optimization, and simulation.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 42, 'total_tokens': 122, 'completion_time': 0.154756005, 'completion_tokens_details': None, 'prompt_time': 0.001907314, 'prompt_tokens_details': None, 'queue_time': 0.012147955, 'total_time': 0.156663319}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019bb57e-bd2a-7970-b1c9-574768ad2750-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 80, 'total_tokens': 122}
