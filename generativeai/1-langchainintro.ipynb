# %%
import langchain
print (langchain.__version__)
# Out:
# 1.2.3

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Generative AI applications with GROQAI Model

# %%
from langchain.chat_models import init_chat_model

# Load Gemini
model = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

# Load Groq
# llm = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

response = model.invoke("write an essay on the topic of the benefits of AI")
print(response.content)
# Out:
# ## The Unfolding Promise: Unlocking the Benefits of Artificial Intelligence
#
# Artificial intelligence (AI), once a realm of science fiction, has rapidly evolved into a pervasive and transformative force, reshaping the contours of modern life. Far from being a mere technological novelty, AI stands as a powerful catalyst for progress, offering an unprecedented array of benefits that span industries, enhance human capabilities, and address some of the world's most pressing challenges. From revolutionizing efficiency and accelerating scientific discovery to personalizing experiences and fostering greater safety, the advantages of AI are profound and continue to unfold.
#
# One of the most immediate and tangible benefits of AI lies in its capacity to dramatically enhance efficiency and productivity across virtually every sector. By automating repetitive, labor-intensive, and data-heavy tasks, AI frees human capital to focus on more creative, strategic, and empathetic endeavors. In manufacturing, AI-powered robotics streamline production lines, reducing errors and increasing output. In logistics, AI optimizes supply chains, predicting demand, managing inventory, and routing deliveries with unparalleled precision. Businesses leverage AI for predictive analytics, identifying market trends, personalizing customer interactions, and making data-driven decisions that boost profitability and competitive advantage. This automation doesn't just cut costs; it creates new avenues for growth and allows organizations to scale operations with unprecedented agility.
#
# Beyond efficiency, AI is proving to be an indispensable engine for scientific discovery and medical breakthroughs. Its ability to process and analyze vast datasets at speeds and scales impossible for humans is accelerating research in areas from drug discovery to climate modeling. In healthcare, AI algorithms are revolutionizing diagnostics, identifying subtle patterns in medical images (like X-rays and MRIs) with greater accuracy than human experts, leading to earlier detection of diseases like cancer. Personalized medicine, once a distant dream, is becoming a reality as AI analyzes individual genetic profiles and health data to tailor treatments for optimal effectiveness. Furthermore, AI is crucial in understanding complex biological systems, accelerating the development of new materials, and modeling intricate environmental phenomena, offering hope for solutions to global challenges like climate change and food security.
#
# The personal realm also experiences significant uplift through AI's capabilities, particularly in personalization and accessibility. AI algorithms power the recommendation engines that tailor content, products, and services to individual preferences, enriching user experiences in entertainment, e-commerce, and education. Adaptive learning platforms utilize AI to customize curricula, identifying a student's strengths and weaknesses and providing targeted resources for more effective learning. Crucially, AI is a powerful tool for accessibility, enabling individuals with disabilities to navigate the world more independently. Speech-to-text and text-to-speech technologies, real-time translation, and AI-powered navigation tools empower millions, breaking down communication barriers and fostering greater inclusivity.
#
# Moreover, AI contributes significantly to safety and risk mitigation across various domains. In hazardous environments, AI-driven robots can perform tasks that are too dangerous for humans, such as inspecting damaged nuclear reactors, defusing bombs, or exploring inhospitable planets. Autonomous vehicles, while still evolving, hold the promise of drastically reducing traffic accidents caused by human error, fatigue, or distraction. AI also plays a critical role in cybersecurity, detecting and neutralizing sophisticated threats faster than human analysts. In disaster management, AI models can predict weather patterns, map flood zones, and optimize emergency response efforts, saving lives and minimizing damage.
#
# While the journey of AI development is not without its ethical considerations and challenges, its overarching benefits are undeniable and transformative. It is a tool that augments human intellect, extends our capabilities, and offers a pathway to a future characterized by greater innovation, efficiency, and well-being. By responsibly harnessing AI's power, fostering ethical development, and ensuring equitable access, humanity stands to unlock an era of unprecedented progress, addressing complex problems and enriching lives in ways that were once unimaginable. The promise of AI is not merely about automation; it is about empowerment – empowering individuals, industries, and indeed, humanity itself, to reach new heights.
