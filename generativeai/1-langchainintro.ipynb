# %%
import langchain
print (langchain.__version__)
# Out:
# 1.2.3

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Generative AI applications with GemeniAI Model

# %%
from langchain.chat_models import init_chat_model

# Load Gemini
model = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

response = model.invoke("write an essay on the topic of the benefits of AI")
print(response.content)
# Out:
# ## The Unfolding Promise: Unpacking the Benefits of Artificial Intelligence
#
# Artificial Intelligence (AI), once a staple of science fiction, has rapidly evolved into a transformative force shaping our present and future. Far from being a mere technological novelty, AI stands as a monumental force for good, promising a future characterized by unprecedented efficiency, groundbreaking innovation, and enriched human experiences across virtually every sector. By augmenting human capabilities, automating mundane tasks, and unveiling insights from vast datasets, AI is proving to be an indispensable tool for progress, prosperity, and problem-solving on a global scale.
#
# One of AI's most immediate and palpable benefits lies in its capacity for automation and efficiency. By performing repetitive, high-volume tasks with speed and accuracy far exceeding human capabilities, AI liberates human workers from monotonous labor. In manufacturing, AI-powered robots enhance production lines, reducing errors and increasing output. In customer service, intelligent chatbots handle routine inquiries, providing instant support and freeing human agents to address more complex issues. This automation not only boosts productivity and lowers operational costs but also allows human employees to pivot towards more creative, strategic, and fulfilling roles that leverage uniquely human skills such as critical thinking, empathy, and innovation.
#
# Beyond mere automation, AI's true analytical prowess shines in its ability to process, interpret, and derive insights from vast datasets at an unparalleled scale. In fields ranging from scientific research to financial analysis, AI algorithms can identify patterns, predict trends, and make informed recommendations with remarkable precision. Medical diagnostics benefit immensely, with AI assisting in the early detection of diseases like cancer by analyzing complex imaging data, often outperforming human specialists. Climate modeling, urban planning, and resource management also leverage AI to understand complex systems, optimize resource allocation, and develop more sustainable solutions. This data-driven insight empowers better decision-making, accelerating discovery and mitigating risks across countless domains.
#
# AI also champions a more human-centric future through its ability to personalize experiences and enhance accessibility. In education, AI-powered learning platforms can adapt to individual student paces and learning styles, offering tailored content and feedback that maximizes comprehension and engagement. In healthcare, precision medicine, driven by AI, analyzes a patient's genetic makeup, lifestyle, and medical history to recommend highly personalized treatment plans. Furthermore, AI-driven assistive technologies are breaking down barriers for individuals with disabilities, offering tools like real-time speech-to-text conversion, image recognition for the visually impaired, and smart prosthetics, thereby fostering greater independence and inclusivity.
#
# Perhaps most profoundly, AI is accelerating the pace of innovation in critical fields that address humanity's grand challenges. In medicine, AI is revolutionizing drug discovery by rapidly screening compounds and predicting their efficacy, significantly shortening development timelines and bringing life-saving treatments to market faster. Environmental monitoring benefits from AI's ability to track pollution, deforestation, and climate change indicators, providing crucial data for conservation efforts. From developing smarter cities with optimized traffic flow and energy grids to enhancing agricultural yields through predictive analytics, AI serves as a powerful catalyst for breakthroughs that improve quality of life and pave the way for a more sustainable future.
#
# In conclusion, the benefits of Artificial Intelligence are vast and transformative, extending far beyond initial expectations. From revolutionizing industries through automation and advanced data analysis to fostering personalized experiences and catalyzing scientific breakthroughs, AI is proving to be an invaluable partner in human progress. While its responsible development and ethical deployment are paramount, the judicious integration of AI promises to unlock a future of unparalleled efficiency, innovation, and human flourishing, augmenting our capabilities and expanding the horizons of what is truly possible. As we continue to harness its potential, AI stands poised to lead us into an era of unprecedented advancement and a better quality of life for all.

# %% [markdown]
# ### Generative AI applications with Groq AI Model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

response = model.invoke("Explain the Artificial Intelligence")
print(response.content)
# Out:
# **Introduction to Artificial Intelligence**
#
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:
#
# 1. **Learning**: AI systems can learn from data and improve their performance over time.
# 2. **Problem-solving**: AI systems can analyze problems and find solutions.
# 3. **Reasoning**: AI systems can draw inferences and make decisions based on available data.
# 4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.
#
# **Types of Artificial Intelligence**
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playing chess.
# 2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.
# 3. **Superintelligence**: An AI system that is significantly more intelligent than the best human minds.
# 4. **Cognitive AI**: Focuses on simulating human thought processes, such as reasoning, decision-making, and problem-solving.
#
# **Key Concepts in Artificial Intelligence**
#
# 1. **Machine Learning**: A subset of AI that involves training algorithms on data to enable them to make predictions or decisions.
# 2. **Deep Learning**: A type of machine learning that uses neural networks to analyze data.
# 3. **Natural Language Processing (NLP)**: The ability of AI systems to understand, interpret, and generate human language.
# 4. **Computer Vision**: The ability of AI systems to interpret and understand visual data from images and videos.
#
# **Applications of Artificial Intelligence**
#
# 1. **Virtual Assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, can perform tasks such as setting reminders, sending messages, and making calls.
# 2. **Image and Speech Recognition**: AI-powered systems can recognize and interpret images and speech, enabling applications such as facial recognition, speech-to-text, and language translation.
# 3. **Autonomous Vehicles**: AI-powered systems can control and navigate vehicles, enabling self-driving cars and trucks.
# 4. **Healthcare**: AI-powered systems can analyze medical data, diagnose diseases, and develop personalized treatment plans.
#
# **Benefits and Challenges of Artificial Intelligence**
#
# **Benefits:**
#
# 1. **Improved Efficiency**: AI can automate repetitive tasks, freeing up human resources for more strategic and creative work.
# 2. **Enhanced Decision-Making**: AI can analyze large datasets and provide insights that can inform decision-making.
# 3. **Personalization**: AI can enable personalized experiences, such as tailored recommendations and customized products.
#
# **Challenges:**
#
# 1. **Job Displacement**: AI can automate jobs, potentially displacing human workers.
# 2. **Bias and Discrimination**: AI systems can perpetuate biases and discrimination if they are trained on biased data.
# 3. **Security and Privacy**: AI systems can pose security and privacy risks if they are not designed and implemented with robust security measures.
#
# **Conclusion**
#
# Artificial Intelligence has the potential to transform numerous aspects of our lives, from healthcare and education to transportation and entertainment. However, it also raises important questions about the future of work, bias and discrimination, and security and privacy. As AI continues to evolve, it is essential to address these challenges and ensure that AI is developed and used in a responsible and beneficial manner.
